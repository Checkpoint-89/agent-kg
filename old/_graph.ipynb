# %% [markdown]
# # Init

# %%
# Notebook specific
from shared.utils.import_utils import import_or_reload

# Load environment variables
from dotenv import load_dotenv
load_dotenv('./.env_staging')

# Configure database connection
import os
from sqlalchemy.engine import URL

db_url = URL.create(
    drivername="postgresql",
    username=os.getenv("DB_USERNAME"),
    password=None,
    host=os.getenv("DB_HOST"),
    port=5432,
    database=os.getenv("DB_DATABASE"),
)

os.environ["SQL_DATABASE_URL"] = db_url.render_as_string(hide_password=True)
from shared.db.session import engine
# Out:
# session.py: successful connexion to PostgreSQL !
# session.py: database URL: postgresql://cedric@easygy-aurora-cluster.cluster-cywqf0ulc6ar.eu-west-3.rds.amazonaws.com:5432/easy_crm_uat

# %% [markdown]
# # Initial Relation Extraction

# %%
# Imports
import json
from typing import cast

import_or_reload("graph.utils.event_retriever")
from graph.utils.event_retriever import get_opportunity_events

import_or_reload("shared.models.event_base")
from shared.models.event_base import EventBaseModel

import_or_reload("shared.semantics.model_configs.semantic_model")
import_or_reload("shared.semantics.semantic_function")
from shared.semantics.semantic_function import run_semantic_pipeline

import_or_reload("graph.utils.event_filter")
from graph.utils.event_filter import create_business_relevance_config

import_or_reload("shared.models.graph_base")
from shared.models.graph_base import EventRelations, Relation, Entity

# Get the records from the table event for an opportunity
# with the concatenated column fomatted (string)
print("\n*****************\nRetrieving events for the opportunity...")
events_df = get_opportunity_events(
    engine,
    opportunity_id="006IV00000f2fykYAA", 
    limit=20)
print(f"Number of events for the opportunity: {len(events_df)}")

# Convert to a dictionary of EventBaseModel with event_id as key
event_dict: dict[str, EventBaseModel] = {}
for record in events_df.to_dict(orient="records"):
    record['formatted'] = json.loads(record['formatted'])
    event_dict[record["event_id"]] = EventBaseModel(**record) # type: ignore

# Filter the relevant events
print("\n*****************\nFiltering relevant events...")
semantic_payload_config = {
    "item_table": "event",
    "table_schema":  "crm_assistant",
    "id_column": "event_id",
    "type_column": "field",
}

results, _ = await run_semantic_pipeline(
    item_ids = list(event_dict.keys()),
    semantic_function_str = "filter",
    semantic_function_config = create_business_relevance_config,
    semantic_payload_config = semantic_payload_config,
    llm_model = "gpt-4o-mini",
    batch_size = 500,
    overwrite = False,
    client = None
)

is_relevant = [item.result_value_.get("is_relevant", False)
               if item.result_value_ is not None
               else False
               for item in results.get("processed", [])]

event_dict = {
    event_id: event_dict[event_id]
    for event_id, is_relevant in zip(event_dict.keys(), is_relevant)
    if is_relevant
}
print(f"Number of relevant events after filtering: {len(event_dict)}")

# Extract relations from the relevant events
print("\n*****************\nExtract relations...")

results, _ = await run_semantic_pipeline(
    item_ids = list(event_dict.keys()),
    semantic_function_str = "extract_relations",
    semantic_function_config = {},
    semantic_payload_config = semantic_payload_config,
    llm_model = "gpt-4o-mini",
    batch_size = 100,
    overwrite = True,
    client = None
)
# Out:
# *****************
# Retrieving events for the opportunity...
# Reading from S3: 100%|██████████| 20/20 [00:00<00:00, 35.26it/s]
# Number of events for the opportunity: 20
#
# *****************
# Filtering relevant events...
# Processing batch 1/1 events
#
# [process_pipeline] - Processed items: 20
#
# [process_pipeline] - Pass-through items: 0
# [process_pipeline] - Missing items: 0
#
# [process_pipeline] - No S3 upload needed.
#
# [process_pipeline] - No rows to upload to DB.
# [from_semantic_table_to_response_model] - Reading 20 cached items from the semantic result table.
# Reading from S3: 100%|██████████| 20/20 [00:00<00:00, 99.48it/s]
# [from_semantic_table_to_response_model] - Reading 20 S3 payloads.
# Reading from S3: 100%|██████████| 20/20 [00:00<00:00, 92.00it/s]
# Number of relevant events after filtering: 12
#
# *****************
# Extract relations...
# Processing batch 1/1 events
#
# [process_pipeline] - Overwriting results - - Considering processed items: 0.
#
# [process_pipeline] - Pass-through items: 0
# [process_pipeline] - Missing items: 12
# Reading from S3: 100%|██████████| 12/12 [00:00<00:00, 74.86it/s]
# Processing extract_relations events:  50%|█████     | 6/12 [00:36<00:34,  5.70s/it]
# [extract_relations] Exception for event '{"type": "transcription", "from": "Thibault Boyer"...':<
# 1 validation error for ExtractRelationsModel
# relations.1.roles.themes.0
#   Value error, Le label 'Dossier' est trop générique. Utilisez un label métier plus spécifique. N'utilise pas les termes suivants: agent, theme, trigger, purpose, reason, instrument, beneficiary, context, origin, destination, co_agent, location, time, personne, organisation, lieu, objet, concept, événement, document, information, donnée, dossier. [type=value_error, input_value={'label': 'Dossier', 'nam...ande.', 'role': 'theme'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/value_error.
# Returning default response.
# Processing extract_relations events: 100%|██████████| 12/12 [00:54<00:00,  4.53s/it]
# [process_pipeline] - Processed missing items: 12
#
# [process_pipeline] - Uploading to S3...
# Uploading to S3: 100%|██████████| 11/11 [00:02<00:00,  3.97it/s]
# [process_pipeline] - Uploading to DB...
# Uploading data: 100%|██████████| 12/12 [00:01<00:00,  9.71it/s]
# total_processed 12
# inserted 12
# rejected 0

# %%
from shared.models.graph_base import EventRelations, Relation, Entity

print("\n*****************\nCollect relations and fill metadata...")
metadata = {}
metadata_keys = ['id_', 'status_', 'type_', 'date_', 's3_path_', 'result_value_']

relations: list[Relation] = []
entities: list[Entity] = []

for event_relations in results['processed']:
    for key in metadata_keys:
        metadata[key] = getattr(event_relations, key)
    for i, relation in enumerate(event_relations.relations):
        relation.metadata = metadata.copy()
        relations.append(relation)
        for roles in relation.roles:
            for entity in roles[1]:
                entity.metadata = metadata.copy()
                entities.append(entity)
print(f"Number of relations extracted: {len(relations)}")

for relation in relations:
    print("\n*****************")
    print(f"\nEvent n°{relation.metadata['id_']}")
    print(f"\nContexte: {relation.description}")
    print(f"-> {relation.relation_type.verb}")
    print(f"-> {relation.relation_type.target_category}")
    print(f"-> {relation.relation_type.label}")
    print(f"-> {relation.relation_type.definition}")
    print("\n")
    for role in relation.roles:
        print(f"{role[0]:<21} |") 
        if role[1]:
            for entity in role[1]:
                print(f"  --- {entity.role:<15} | {entity.label:<25} | {entity.name:<20}")
# Out:
# *****************
# Collect relations and fill metadata...
# Number of relations extracted: 34
#
# *****************
#
# Event n°148262172
#
# Contexte: Thibault Boyer informe Raphaël Cohen qu'il a pu faire une offre pour l'hôtel Astres, mais que celle-ci a été invalidée en interne car le client était déjà chez un autre fournisseur.
# -> INFORMER
# -> offre
# -> INFORMER_OFFRE
# -> Action de communiquer des informations concernant une proposition commerciale.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Offre                     | Offre Pour L'Hôtel Astres
# circumstances         |
#   --- reason          | Raison                    | Client Déjà Chez Un Autre Fournisseur
# context               |
#   --- context         | Communication             | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°148262172
#
# Contexte: Raphaël Cohen informe Thibault Boyer qu'il va prévenir le commercial suite à l'invalidation de l'offre pour l'hôtel Astres.
# -> INFORMER
# -> commercial
# -> INFORMER_COMMERCIAL
# -> Action de communiquer des informations concernant un changement dans la gestion des offres.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Commercial                | Thibault Boyer
# themes                |
#   --- theme           | Commercial                | Commercial
# circumstances         |
#   --- reason          | Raison                    | Invalidation De L'Offre
# context               |
#   --- context         | Communication             | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°148262172
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent des difficultés à renouveler des contrats avec des clients déjà engagés avec d'autres fournisseurs.
# -> DISCUTER
# -> renouvellement de contrats
# -> DISCUTER_RENOUVELLEMENT_DE_CONTRATS
# -> Action de parler des enjeux liés à la prolongation d'accords commerciaux.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Contrat                   | Renouvellement De Contrats
# circumstances         |
#   --- reason          | Raison                    | Clients Déjà Engagés
# context               |
#   --- context         | Communication             | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°148262172
#
# Contexte: Raphaël Cohen informe Thibault Boyer qu'il a perdu un client au profit d'EDF, après que le client a consulté un cabinet d'expertise.
# -> INFORMER
# -> client
# -> INFORMER_CLIENT
# -> Action de communiquer des informations concernant la perte d'un client.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Commercial                | Thibault Boyer
# themes                |
#   --- theme           | Client                    | Client Perdu
# circumstances         |
#   --- reason          | Raison                    | Consultation D'Un Cabinet D'Expertise
# context               |
#   --- context         | Communication             | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°148262172
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent de la possibilité de travailler avec un ancien collègue de la mère de Raphaël, qui est directeur d'hôtels Bébé à Dijon.
# -> DISCUTER
# -> négociation
# -> DISCUTER_NEGOCIATION
# -> Action de parler des opportunités de collaboration avec un contact potentiel.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Hôtel                     | Hôtels Bébé
# circumstances         |
#   --- reason          | Raison                    | Possibilité De Négociation
# context               |
#   --- context         | Communication             | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°152998783
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent de la réception d'une facture par Raphaël Cohen pour Oranergy. Thibault confirme que la facture a été reçue et que tout est en ordre.
# -> DISCUTER
# -> facturation
# -> DISCUTER_FACTURATION
# -> Échange d'informations entre deux agents concernant la réception et le traitement d'une facture.
#
#
# agents                |
#   --- agent           | Responsable De La Facturation | Thibault Boyer
#   --- agent           | Client                    | Raphaël Cohen
# themes                |
#   --- theme           | Facture                   | Facture
# circumstances         |
#   --- instrument      | Société                   | Oranergy
# context               |
#   --- context         | Appel Téléphonique        | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°152998783
#
# Contexte: Raphaël Cohen informe Thibault Boyer que Michael Bord n'a pas reçu de facture d'électricité et qu'il n'a pas été prélevé.
# -> INFORMER
# -> facturation
# -> INFORMER_FACTURATION
# -> Communication d'une information concernant l'absence de facture et de prélèvement pour un client.
#
#
# agents                |
#   --- agent           | Client                    | Raphaël Cohen
#   --- agent           | Responsable De La Facturation | Thibault Boyer
# themes                |
#   --- theme           | Facture D'Électricité     | Facture D'Électricité
# circumstances         |
#   --- instrument      | Client                    | Michael Bord
# context               |
#   --- context         | Appel Téléphonique        | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°152998783
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent de la restructuration des équipes de Raphaël et de la manière dont ils vont procéder pour gérer les dossiers en cours.
# -> DISCUTER
# -> gestion des dossiers
# -> DISCUTER_GESTION_DES_DOSSIERS
# -> Échange d'informations sur la gestion et la restructuration des dossiers en cours.
#
#
# agents                |
#   --- agent           | Responsable De La Facturation | Thibault Boyer
#   --- agent           | Client                    | Raphaël Cohen
# themes                |
#   --- theme           | Dossiers                  | Dossiers
# circumstances         |
#   --- instrument      | Restructuration           | Restructuration Des Équipes
# context               |
#   --- context         | Appel Téléphonique        | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°152998783
#
# Contexte: Thibault Boyer et Raphaël Cohen abordent la question de la qualité des dossiers envoyés et de l'importance de cibler les bons clients.
# -> ABORDER
# -> qualité des dossiers
# -> ABORDER_QUALITE_DES_DOSSIERS
# -> Discussion sur l'importance de la qualité des dossiers et du ciblage des clients.
#
#
# agents                |
#   --- agent           | Responsable De La Facturation | Thibault Boyer
#   --- agent           | Client                    | Raphaël Cohen
# themes                |
#   --- theme           | Qualité Des Dossiers      | Qualité Des Dossiers
# circumstances         |
#   --- instrument      | Ciblage                   | Ciblage Des Clients
# context               |
#   --- context         | Appel Téléphonique        | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°125926977
#
# Contexte: Thibault Boyer et Raphaël Cohen échangent des vœux pour la nouvelle année et discutent de leurs vacances respectives, indiquant une relation amicale et professionnelle.
# -> ECHANGER
# -> vœux
# -> ECHANGER_V_UX
# -> Interaction entre deux personnes pour exprimer des souhaits.
#
#
# agents                |
#   --- agent           | Collaborateur             | Thibault Boyer
#   --- agent           | Collaborateur             | Raphaël Cohen
# themes                |
#   --- theme           | Vœux                      | Meilleurs Vœux
# circumstances         |
#   --- trigger         | Contexte                  | Nouvelle Année
# context               |
#   --- context         | Contexte                  | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°125926977
#
# Contexte: Thibault Boyer informe Raphaël Cohen qu'il travaille sur des contrats et qu'il va passer la direction pour les revoir.
# -> REVOIR
# -> contrats
# -> REVOIR_CONTRATS
# -> Action de réexaminer des accords formels entre parties.
#
#
# agents                |
#   --- agent           | Collaborateur             | Thibault Boyer
# themes                |
#   --- theme           | Contrat                   | Contrats
# circumstances         |
#   --- trigger         | Contexte                  | Travail
# context               |
#   --- context         | Contexte                  | Direction
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°125926977
#
# Contexte: Raphaël Cohen attend que Thibault Boyer lui fasse parvenir son contrat pour pouvoir établir des contrats avec d'autres prestataires.
# -> ATTENDRE
# -> contrats
# -> ATTENDRE_CONTRATS
# -> Action de rester dans l'état d'attente pour recevoir un document.
#
#
# agents                |
#   --- agent           | Collaborateur             | Raphaël Cohen
# themes                |
#   --- theme           | Contrat                   | Contrats
# circumstances         |
#   --- trigger         | Contexte                  | Attente
# context               |
#   --- context         | Contexte                  | Prestataires
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°125926977
#
# Contexte: Thibault Boyer explique à Raphaël Cohen que les contrats de type CD ne peuvent pas être établis par texto en raison de la nécessité d'une signature électronique.
# -> EXPLIQUER
# -> contrats
# -> EXPLIQUER_CONTRATS
# -> Action de clarifier les conditions d'établissement d'accords formels.
#
#
# agents                |
#   --- agent           | Collaborateur             | Thibault Boyer
# themes                |
#   --- theme           | Contrat                   | Contrats Cd
# circumstances         |
#   --- trigger         | Contexte                  | Signature Électronique
# context               |
#   --- context         | Contexte                  | Fraude
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°125926977
#
# Contexte: Raphaël Cohen discute des différences entre l'envoi de contrats par mail et par texto, soulignant les risques de fraude associés à chaque méthode.
# -> DISCUTER
# -> méthodes de communication
# -> DISCUTER_METHODES_DE_COMMUNICATION
# -> Action d'échanger des idées ou des opinions sur un sujet.
#
#
# agents                |
#   --- agent           | Collaborateur             | Raphaël Cohen
# themes                |
#   --- theme           | Contrat                   | Contrats
# circumstances         |
#   --- trigger         | Contexte                  | Fraude
# context               |
#   --- context         | Contexte                  | Communication
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°145107867
#
# Contexte: Thibault Boyer discute avec Raphaël Cohen au sujet d'un client qui a rappelé pour un devis. Ils parlent de la simulation à réaliser pour le raccordement prévu par un conseiller.
# -> DISCUTER
# -> devis
# -> DISCUTER_DEVIS
# -> Interaction entre deux agents concernant un devis et un raccordement.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Client                    | Client
# circumstances         |
#   --- purpose         | Objectif                  | Raccordement
# context               |
#   --- context         | Contexte                  | Devis
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°145107867
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent de la mise en service d'un raccordement électrique prévue pour début mars.
# -> PREVOIR
# -> mise en service
# -> PREVOIR_MISE_EN_SERVICE
# -> Action de planifier la mise en service d'un raccordement électrique.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Raccordement              | Raccordement Électrique
# circumstances         |
#   --- purpose         | Objectif                  | Mise En Service
# context               |
#   --- context         | Contexte                  | Date De Mise En Service
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°145107867
#
# Contexte: Thibault Boyer et Raphaël Cohen échangent sur un client qui a signé un contrat et qui souhaite se rétracter en raison de conditions jugées défavorables.
# -> SIGNER
# -> contrat
# -> SIGNER_CONTRAT
# -> Action de conclure un accord légal entre un client et un fournisseur.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Client                    | Client Insatisfait
# circumstances         |
#   --- reason          | Raison                    | Conditions Défavorables
# context               |
#   --- context         | Contexte                  | Contrat
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°111146615
#
# Contexte: Thibault Boyer discute avec Raphaël Cohen au sujet de l'envoi de documents et de la communication avec un client. Ils abordent la question des plaquettes informatiques et de la nécessité de mettre en copie les bonnes personnes dans les échanges d'emails. Thibault s'engage à renvoyer les informations nécessaires à Raphaël et à s'assurer que la communication avec le client se déroule correctement.
# -> DISCUTER
# -> communication
# -> DISCUTER_COMMUNICATION
# -> Interaction entre deux agents pour échanger des informations et coordonner des actions.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Client                    | Raphaël Cohen
# themes                |
#   --- theme           | Documents                 | Documents
# circumstances         |
#   --- reason          | Raison                    | Communication Client
# context               |
#   --- context         | Société                   | Oranergy
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°122471194
#
# Contexte: Raphaël Cohen demande à Thibault Boyer s'il est possible de faire des contrats au nom de deux sociétés différentes, car il souhaite que l'un des contrats soit au nom de la holding et l'autre au nom d'une autre société.
# -> DEMANDER
# -> contrat
# -> DEMANDER_CONTRAT
# -> Action de solliciter une information ou un service concernant la possibilité de créer des contrats au nom de différentes entités.
#
#
# agents                |
#   --- agent           | Interlocuteur             | Raphaël Cohen
#   --- agent           | Interlocuteur             | Thibault Boyer
# themes                |
#   --- theme           | Contrat                   | Contrats Au Nom De Deux Sociétés
# circumstances         |
#   --- trigger         | Demande                   | Demande De Raphaël Cohen
# context               |
#   --- context         | Appel                     | Appel Téléphonique Entre Raphaël Cohen Et Thibault Boyer
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°122471194
#
# Contexte: Thibault Boyer s'engage à demander aux parties concernées si les contrats peuvent être établis au nom de deux sociétés différentes.
# -> DEMANDER
# -> contrat
# -> DEMANDER_CONTRAT
# -> Action de solliciter une information ou un service concernant la possibilité de créer des contrats au nom de différentes entités.
#
#
# agents                |
#   --- agent           | Interlocuteur             | Thibault Boyer
# themes                |
#   --- theme           | Contrat                   | Contrats Au Nom De Deux Sociétés
# circumstances         |
#   --- trigger         | Engagement                | Engagement De Thibault Boyer
# context               |
#   --- context         | Appel                     | Appel Téléphonique Entre Raphaël Cohen Et Thibault Boyer
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°122471194
#
# Contexte: Raphaël Cohen et Thibault Boyer discutent de la nécessité de récupérer des RIB pour finaliser les contrats.
# -> RECUPERER
# -> RIB
# -> RECUPERER_RIB
# -> Action de collecter ou obtenir des documents bancaires nécessaires pour finaliser des contrats.
#
#
# agents                |
#   --- agent           | Interlocuteur             | Raphaël Cohen
#   --- agent           | Interlocuteur             | Thibault Boyer
# themes                |
#   --- theme           | Rib                       | Récupération Des Rib
# circumstances         |
#   --- trigger         | Discussion                | Discussion Sur Les Rib
# context               |
#   --- context         | Appel                     | Appel Téléphonique Entre Raphaël Cohen Et Thibault Boyer
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°122471194
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent des délais pour la signature des contrats, en précisant que les contrats doivent être prêts pour 16h30.
# -> SIGNER
# -> contrat
# -> SIGNER_CONTRAT
# -> Action de ratifier un accord légal entre deux parties dans un délai imparti.
#
#
# agents                |
#   --- agent           | Interlocuteur             | Thibault Boyer
#   --- agent           | Interlocuteur             | Raphaël Cohen
# themes                |
#   --- theme           | Contrat                   | Signature Des Contrats
# circumstances         |
#   --- trigger         | Délai                     | Délai De Signature
# context               |
#   --- context         | Appel                     | Appel Téléphonique Entre Raphaël Cohen Et Thibault Boyer
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°122471194
#
# Contexte: Raphaël Cohen informe Thibault Boyer qu'il doit rappeler un client pour discuter d'un contrat.
# -> RAPPELER
# -> client
# -> RAPPELER_CLIENT
# -> Action de recontacter un client pour obtenir des informations ou finaliser un accord.
#
#
# agents                |
#   --- agent           | Interlocuteur             | Raphaël Cohen
# themes                |
#   --- theme           | Client                    | Appel À Un Client
# circumstances         |
#   --- trigger         | Rappel                    | Rappel D'Un Client
# context               |
#   --- context         | Appel                     | Appel Téléphonique Entre Raphaël Cohen Et Thibault Boyer
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°130674754
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent d'une signature électronique pour un client, où Raphaël a aidé le client à signer un document. Thibault doit vérifier si la signature a été reçue et renvoyer le document si nécessaire.
# -> SIGNER
# -> document
# -> SIGNER_DOCUMENT
# -> Action de faire approuver un document par une personne par le biais d'une signature électronique.
#
#
# agents                |
#   --- agent           | Responsable De La Signature | Thibault Boyer
#   --- agent           | Assistant Client          | Raphaël Cohen
# themes                |
#   --- theme           | Client                    | Client
# circumstances         |
#   --- trigger         | Action                    | Signature Électronique
# context               |
#   --- context         | Contexte                  | Oranergy
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°212088448
#
# Contexte: Thibault Boyer informe Raphaël Cohen de la situation actuelle d'Oranergy, notamment sur la fermeture de l'entreprise durant le mois d'août et les difficultés rencontrées dans la prospection de nouveaux clients.
# -> INFORMER
# -> situation d'entreprise
# -> INFORMER_SITUATION_D_ENTREPRISE
# -> Action de communiquer des informations sur l'état ou la situation d'une entreprise à un interlocuteur.
#
#
# agents                |
#   --- agent           | Responsable D'Entreprise  | Thibault Boyer
#   --- agent           | Collaborateur             | Raphaël Cohen
# themes                |
#   --- theme           | Société                   | Oranergy
# circumstances         |
#   --- reason          | Fermeture D'Entreprise    | Fermeture D'Oranergy
# context               |
#   --- context         | Période                   | Mois D'Août
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°141283592
#
# Contexte: Raphaël Cohen informe Thibault Boyer qu'il a eu un contact avec un commercial qui souhaite un contrat de courte durée pour se porter garant, et discute des sociétés à choisir pour cette garantie.
# -> DISCUTER
# -> contrat
# -> DISCUTER_CONTRAT
# -> Action de négocier les termes d'un contrat commercial.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Négociateur               | Thibault Boyer
# themes                |
#   --- theme           | Société                   | Sociétés À Choisir Pour La Garantie
# circumstances         |
#   --- purpose         | Durée                     | 1 Ou 2 Ans Max
# context               |
#   --- context         | Contexte Commercial       | Négociation De Contrat
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°141283592
#
# Contexte: Thibault Boyer et Raphaël Cohen discutent des sociétés à choisir pour la garantie, en se préoccupant de leur notation.
# -> CHOISIR
# -> société
# -> CHOISIR_SOCIETE
# -> Action de sélectionner des entités commerciales pour un contrat.
#
#
# agents                |
#   --- agent           | Négociateur               | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Société                   | Sociétés À Choisir Pour La Garantie
# circumstances         |
#   --- reason          | Notation                  | Sociétés Mal Notées
# context               |
#   --- context         | Contexte Commercial       | Sélection De Sociétés
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°141283592
#
# Contexte: Raphaël Cohen demande à Thibault Boyer d'envoyer une lettre de résiliation pour des clients.
# -> DEMANDER
# -> résiliation
# -> DEMANDER_RESILIATION
# -> Action de solliciter un document pour mettre fin à un contrat.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Négociateur               | Thibault Boyer
# themes                |
#   --- theme           | Lettre De Résiliation     | Demande De Lettre De Résiliation
# circumstances         |
#   --- beneficiary     | Clients                   | Clients À Résilier
# context               |
#   --- context         | Contexte Commercial       | Gestion Des Contrats
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°141283592
#
# Contexte: Thibault Boyer informe Raphaël Cohen des détails concernant un client et la nécessité d'un contrat unique pour tous les sites.
# -> NEGOCIER
# -> contrat unique
# -> NEGOCIER_CONTRAT_UNIQUE
# -> Action de discuter pour établir un contrat regroupant plusieurs entités.
#
#
# agents                |
#   --- agent           | Négociateur               | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Client                    | Client Avec Plusieurs Contrats
# circumstances         |
#   --- purpose         | Contrat Unique            | Nécessité D'Un Contrat Unique
# context               |
#   --- context         | Contexte Commercial       | Négociation De Contrat
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°110354948
#
# Contexte: Thibault Boyer discute avec Raphaël Cohen de l'envoi de documents et de la gestion des factures entre leurs sociétés respectives. Thibault préfère recevoir les factures par email au format PDF plutôt que via un service de stockage en ligne, car il n'a pas accès à ce dernier. Ils conviennent d'utiliser des objets de mail clairs pour faciliter le suivi des communications et des documents. Raphaël explique qu'il s'occupe de la partie commerciale et qu'il transfère les informations nécessaires à Thibault pour le suivi des clients.
# -> DISCUTER
# -> documents
# -> DISCUTER_DOCUMENTS
# -> Échange d'informations et de décisions concernant la gestion des documents et des factures entre deux agents.
#
#
# agents                |
#   --- agent           | Responsable Communication | Thibault Boyer
#   --- agent           | Responsable Commercial    | Raphaël Cohen
# themes                |
#   --- theme           | Échange De Documents      | Documents
# circumstances         |
#   --- instrument      | Moyen De Communication    | Email
# context               |
#   --- context         | Société                   | Société Oranergy
#   --- context         | Société                   | Société Steve
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°134444699
#
# Contexte: Raphaël Cohen informe Thibault Boyer que le client SMC Le Bergerac a validé une offre de caution de 400 euros au lieu de 1900 euros. Il demande également si Thibault a reçu un retour concernant le dépôt de la liasse fiscale nécessaire pour faire le comparatif en gaz.
# -> INFORMER
# -> offre
# -> INFORMER_OFFRE
# -> Action de communiquer des informations concernant une offre commerciale.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Commercial                | Thibault Boyer
# themes                |
#   --- theme           | Client                    | Smc Le Bergerac
# circumstances         |
#   --- reason          | Condition                 | Dépôt De La Liasse Fiscale
# context               |
#   --- context         | Contexte                  | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°134444699
#
# Contexte: Thibault Boyer indique à Raphaël Cohen qu'il attend un retour concernant le dépôt de la liasse fiscale pour le comparatif en gaz.
# -> ATTENDRE
# -> retour
# -> ATTENDRE_RETOUR
# -> Action de rester en attente d'une réponse ou d'une information.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Dossier De Comparatif     | Dossier De Comparatif En Gaz
# circumstances         |
#   --- reason          | Condition                 | Retour Sur Le Dépôt De La Liasse Fiscale
# context               |
#   --- context         | Contexte                  | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°134444699
#
# Contexte: Thibault Boyer demande à Raphaël Cohen de lui renvoyer la liasse fiscale pour le dossier de comparatif en gaz.
# -> DEMANDER
# -> document
# -> DEMANDER_DOCUMENT
# -> Action de solliciter un document ou une information.
#
#
# agents                |
#   --- agent           | Commercial                | Thibault Boyer
#   --- agent           | Commercial                | Raphaël Cohen
# themes                |
#   --- theme           | Liasse Fiscale            | Liasse Fiscale
# circumstances         |
#   --- reason          | Condition                 | Dossier De Comparatif En Gaz
# context               |
#   --- context         | Contexte                  | Appel Téléphonique
# origin_destinations   |
# time_locations        |
#
# *****************
#
# Event n°134444699
#
# Contexte: Raphaël Cohen informe Thibault Boyer qu'il a besoin d'un contrat de la Belle Énergie pour le client SMC Le Bergerac.
# -> DEMANDER
# -> contrat
# -> DEMANDER_CONTRAT
# -> Action de solliciter un accord formel entre parties.
#
#
# agents                |
#   --- agent           | Commercial                | Raphaël Cohen
#   --- agent           | Commercial                | Thibault Boyer
# themes                |
#   --- theme           | Client                    | Smc Le Bergerac
#   --- theme           | Fournisseur               | Belle Énergie
# circumstances         |
#   --- reason          | Condition                 | Contrat
# context               |
#   --- context         | Contexte                  | Appel Téléphonique
# origin_destinations   |
# time_locations        |

# %% [markdown]
# # Cluster and Generate Models

# %%
import openai
import instructor
from instructor import AsyncInstructor, Mode

import_or_reload("shared.models.graph_base")
from shared.models.graph_base import RelationTypeClusters

import_or_reload("graph.utils.clustering")
from graph.utils.clustering import get_artefacts_clusters, sub_cluster, synth_clusters

import_or_reload("graph.graph_converter")
from graph.graph_converter import generate_py

#Get clusters from the relations
print("\n*****************\nGet relation clusters...")
embds_clusters  = get_artefacts_clusters(relations)

# Sub-cluster the clusters by relation types
print("\n*****************\nSub-cluster relations by types...")
llm_model = 'gpt-4o-mini'
client: AsyncInstructor = instructor.patch(
                openai.AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY")),
                mode=Mode.TOOLS_STRICT,
            ) # type: ignore

relation_type_clusters_list: list[RelationTypeClusters] = await sub_cluster(
    clusters=embds_clusters,
    client=client,
    llm_model=llm_model
) # Each element of the list is a cluster of relation types

# Synthesize the clusters
# TODO: make synth_clusters() faster
print("\n*****************\nSynthetize clusters...")
relation_type_clusters = await synth_clusters(
    relation_type_clusters=relation_type_clusters_list,
    client=client,
    llm_model='o3',
    max_examples_for_synthesis=200
)
print("Done. Number of clusters synthesized: ", len(relation_type_clusters.clusters))

# Generate business relation type models from the clusters and save to file
print("\n*****************\nGenerate business relation type models...")
file_str = generate_py(
    relation_type_clusters,
    save_to_file=True,
    file_path="shared/models/biz_relation_types.py"
)
# Out:
# *****************
# Get relation clusters...
# Computing embeddings using model text-embedding-3-small
# Calling OpenAI API for 34 embeddings
# Processing batch #1 with 34 items...
# Attaching embeddings to items
# Number of relations: 34
# Number of items to embed: 34
# Number of computed embeddings: 34
# Cumulative explained variance:  0.7743118112483961
# Number of PCA components:  12
# UMAP embedding shape:  (34, 12)
# Number of clusters found: 2
# Number of data points: 34
# Number of noise points: 2
#
# *****************
# Sub-cluster relations by types...
# Preparing task for cluster 0 (1/2), which has 7 examples.
# Preparing task for cluster 1 (2/2), which has 25 examples.
#
# Executing 2 sub-clustering tasks in parallel...
#
# *****************
# Synthetize clusters...
# Done. Number of clusters synthesized:  5
#
# *****************
# Generate business relation type models...

# %%
import openai
import instructor
from instructor import AsyncInstructor, Mode

import_or_reload("shared.models.graph_base")
from shared.models.graph_base import RelationTypeClusters, EntityTypeClusters

import_or_reload("graph.utils.clustering")
from graph.utils.clustering import get_artefacts_clusters, sub_cluster, synth_clusters

import_or_reload("graph.graph_converter")
from graph.graph_converter import generate_py
type = 'entity'

#Get clusters from the artefacts
print("\n*****************\nGet artefact clusters...")
embds_clusters  = get_artefacts_clusters(entities)


# Sub-cluster the clusters by artefact types
print("\n*****************\nSub-cluster artefacts by types...")
llm_model = 'gpt-4o-mini'
client: AsyncInstructor = instructor.patch(
                openai.AsyncOpenAI(api_key=os.getenv("OPENAI_API_KEY")),
                mode=Mode.TOOLS_STRICT,
            ) # type: ignore

artefact_type_clusters_list: list[EntityTypeClusters] = await sub_cluster(
    clusters=embds_clusters,
    client=client,
    llm_model=llm_model,
    type=type
) # Each element of the list is a cluster of entity types
# Out:
# *****************
# Get artefact clusters...
# Computing embeddings using model text-embedding-3-small
# Calling OpenAI API for 166 embeddings
# Processing batch #1 with 166 items...
# Attaching embeddings to items
# Number of relations: 166
# Number of items to embed: 166
# Number of computed embeddings: 166
# Cumulative explained variance:  0.7595825792795968
# Number of PCA components:  21
# UMAP embedding shape:  (166, 15)
# Number of clusters found: 24
# Number of data points: 166
# Number of noise points: 15
#
# *****************
# Sub-cluster artefacts by types...
# Preparing task for cluster 0 (1/24), which has 6 examples.
# Preparing task for cluster 1 (2/24), which has 8 examples.
# Preparing task for cluster 2 (3/24), which has 5 examples.
# Preparing task for cluster 3 (4/24), which has 4 examples.
# Preparing task for cluster 4 (5/24), which has 5 examples.
# Preparing task for cluster 5 (6/24), which has 8 examples.
# Preparing task for cluster 6 (7/24), which has 5 examples.
# Preparing task for cluster 7 (8/24), which has 8 examples.
# Preparing task for cluster 8 (9/24), which has 4 examples.
# Preparing task for cluster 9 (10/24), which has 6 examples.
# Preparing task for cluster 10 (11/24), which has 4 examples.
# Preparing task for cluster 11 (12/24), which has 6 examples.
# Preparing task for cluster 12 (13/24), which has 9 examples.
# Preparing task for cluster 13 (14/24), which has 5 examples.
# Preparing task for cluster 14 (15/24), which has 12 examples.
# Preparing task for cluster 15 (16/24), which has 6 examples.
# Preparing task for cluster 16 (17/24), which has 6 examples.
# Preparing task for cluster 17 (18/24), which has 8 examples.
# Preparing task for cluster 18 (19/24), which has 7 examples.
# Preparing task for cluster 19 (20/24), which has 8 examples.
# Preparing task for cluster 20 (21/24), which has 4 examples.
# Preparing task for cluster 21 (22/24), which has 6 examples.
# Preparing task for cluster 22 (23/24), which has 5 examples.
# Preparing task for cluster 23 (24/24), which has 6 examples.
#
# Executing 24 sub-clustering tasks in parallel...

# %%
for cl in artefact_type_clusters_list:
    clusters = cl.clusters
    for cluster in cl.clusters:
        print(f"Cluster label: {cluster.name}")
# Out:
# Cluster label: COLLABORATEUR
# Cluster label: COLLABORATEUR_ADMINISTRATIF
# Cluster label: COLLABORATEUR_TECHNIQUE
# Cluster label: COLLABORATEUR_COMMERCIAL
# Cluster label: INTERLOCUTEUR
# Cluster label: COMMUNICATION_VERBALE_PROFESSIONNELLE
# Cluster label: APPELS_TELEPHONIQUES_ADMINISTRATIFS
# Cluster label: APPEL
# Cluster label: COMMERCIAUX
# Cluster label: NEGOCIATEURS
# Cluster label: COMMERCIAL
# Cluster label: COMMERCIAUX
# Cluster label: RESPONSABLE_COMMERCIAL
# Cluster label: RESPONSABLE_DE_LA_FACTURATION
# Cluster label: COMMERCIAUX
# Cluster label: RESPONSABLES_DE_LA_SIGNATURE
# Cluster label: GESTION_DES_SIGNATURES_ELECTRONIQUES
# Cluster label: ASSISTANCE_CLIENT_ET_ACTIONS_DE_SIGNATURE
# Cluster label: DOCUMENTS_ET_ACCORDS_FORMELS
# Cluster label: INTERACTIONS_ET_NEGOCIATIONS_COMMERCIALES
# Cluster label: CONTRATS_FORMELS
# Cluster label: CONTRAT_UNIQUE
# Cluster label: CLIENTS
# Cluster label: FOURNISSEURS
# Cluster label: OPERATIONS
# Cluster label: ROLES_COMMERCIAUX
# Cluster label: ROLES_DE_GESTION_ET_COMMUNICATION
# Cluster label: TEMPORALITE_ET_ETAT
# Cluster label: ROLES_ET_RESPONSABILITES
# Cluster label: COMPORTEMENTS_ET_ACTIONS
# Cluster label: INTERACTIONS_COMMERCIALES
# Cluster label: ECHANGES_D_INFORMATIONS
# Cluster label: SOCIETES_DE_FOURNITURE_D_ENERGIE
# Cluster label: SOCIETES_DE_GARANTIE
# Cluster label: FACTURES
# Cluster label: COMPARATIFS_DE_GAZ
# Cluster label: GESTION_DES_DOSSIERS
# Cluster label: COMMUNICATION_ET_ECHANGE_DE_DOCUMENTS
# Cluster label: CIBLAGE_ET_DISCUSSION
# Cluster label: CLIENT
# Cluster label: CLIENTS_ET_RELATIONS_COMMERCIALES
# Cluster label: OBSTACLES_A_LA_CONCLUSION_D_ACCORDS
# Cluster label: SITUATIONS_FAVORABLES_A_LA_SIGNATURE_DE_CONTRATS
# Cluster label: OFFRES_ET_DEMANDES_DE_SERVICES
# Cluster label: OBJECTIFS_ET_RACCORDEMENTS

# %%
cl
# Out:
# EntityTypeClusters(thinking="Le cluster fourni contient plusieurs occurrences de la même définition pour le terme 'Collaborateur'. Cela indique qu'il n'y a pas de diversité dans les entités présentées, toutes se référant à un même concept. Cependant, pour une analyse plus approfondie, il est possible d'explorer des sous-clusters basés sur des caractéristiques ou des rôles spécifiques que les collaborateurs peuvent avoir au sein d'une entreprise. Par exemple, on pourrait envisager des sous-clusters tels que 'Collaborateur Administratif', 'Collaborateur Technique', 'Collaborateur Commercial', etc. Chacun de ces sous-clusters pourrait avoir des définitions spécifiques qui les distinguent les uns des autres.", clusters=[EntityTypeCluster(name='COLLABORATEUR', definition="Un individu engagé dans des interactions professionnelles au sein d'une entreprise, sans distinction de rôle ou de fonction.", entity_types=[EntityType(label='Collaborateur', definition="Un individu engagé dans des interactions professionnelles au sein d'une entreprise.")]), EntityTypeCluster(name='COLLABORATEUR_ADMINISTRATIF', definition="Un collaborateur dont le rôle principal est de gérer les tâches administratives et de soutien au sein de l'entreprise.", entity_types=[EntityType(label='Collaborateur Administratif', definition="Un individu engagé dans des interactions professionnelles au sein d'une entreprise, principalement axé sur les tâches administratives.")]), EntityTypeCluster(name='COLLABORATEUR_TECHNIQUE', definition="Un collaborateur qui se concentre sur les aspects techniques et opérationnels des projets au sein de l'entreprise.", entity_types=[EntityType(label='Collaborateur Technique', definition="Un individu engagé dans des interactions professionnelles au sein d'une entreprise, avec un accent sur les compétences techniques.")]), EntityTypeCluster(name='COLLABORATEUR_COMMERCIAL', definition="Un collaborateur dont le rôle est de promouvoir et de vendre les produits ou services de l'entreprise.", entity_types=[EntityType(label='Collaborateur Commercial', definition="Un individu engagé dans des interactions professionnelles au sein d'une entreprise, axé sur les ventes et le marketing.")])])

# %% [markdown]
# # Relation Extraction

# %%
import asyncio
from typing import Coroutine, Any, Union

import_or_reload("shared.models.biz_relation_types")
from shared.models.biz_relation_types import UNION_CLUSTERS, DICT_CLUSTERS

# Create a list of all tasks (coroutines) to be executed.
tasks: list[Coroutine[Any, Any, list[UNION_CLUSTERS]]] = []
for v in event_dict.values():
    prompt = f"""
    Classify the following event into the appropriate business clusters. To be classified, the event must provide relevant information about that cluster as it will be used downstream to extract that information:
    ##########################
    {json.dumps(v.formatted)}
    ##########################
    """

    llm_model = 'gpt-4o-mini'
    task = client.chat.completions.create(
        model=llm_model,
        messages=[
            {
                "role": "system",
                "content": prompt,
            },
        ],
        temperature=0.0 if llm_model != 'o3' else 1.0, # type: ignore
        max_retries=2,
        response_model=list[UNION_CLUSTERS], # type: ignore
        timeout=30,
    )
    tasks.append(task)

# Execute all tasks concurrently and wait for all of them to complete.
# The 'await' is here, on the entire set of tasks.
all_clusters_results = await asyncio.gather(*tasks)

# Associate the results with their corresponding events.
for event, clusters_for_event in zip(event_dict.values(), all_clusters_results):
    event.metadata = {}
    if 'clusters' not in event.metadata:
        event.metadata['clusters'] = {}
    for cluster in clusters_for_event:
        event.metadata['clusters'][cluster.name] = {
            "cluster": cluster,
        }

# Create a cluster to events mapping.
from collections import defaultdict
cluster_to_events: dict[str, list[str]] = defaultdict(list)

#---Iterate through each event in the event_dict.
for event_id, event in event_dict.items():
    if event.metadata and 'clusters' in event.metadata:
        clusters_in_event = event.metadata['clusters']
        for cluster_name in clusters_in_event.keys():
            cluster_to_events[cluster_name].append(event_id)

#--- Convert the defaultdict back to a regular dictionary for cleaner output (optional).
cluster_to_events = dict(cluster_to_events)

#--- Display the resulting dictionary.
n_events = sum([1 for cluster_list in cluster_to_events.values() for _ in cluster_list])
print(f"Found {len(cluster_to_events)} unique clusters referencing {n_events} events in total")

# %%
import_or_reload("shared.models.graph_base")
import_or_reload("shared.semantics.model_configs.extract_biz_relations_model")
import_or_reload("shared.semantics.semantic_function")
from shared.semantics.semantic_function import SemanticFunction

tasks: list[Coroutine[Any, Any, tuple[dict[str, Any], SemanticFunction]]] = []

#shortened = {k: cluster_to_events[k] for k in list(cluster_to_events.keys())[0:1]}
shortened = cluster_to_events
for cluster_name, event_ids in shortened.items():

    print("Processing cluster: ", cluster_name)
    BizRelationType = Union[tuple(DICT_CLUSTERS[cluster_name])]
    print("\nThis cluster has the following biz relation types: ", BizRelationType)

    semantic_payload_config: dict[str, str|bool] = {
        "item_table": "event",
        "table_schema":  "crm_assistant",
        "id_column": "event_id",
        "type_column": "field",
        "include_source": False,
    }
    
    task = run_semantic_pipeline(
    item_ids = event_ids,
    semantic_function_str = "extract_biz_relations",
    semantic_function_config = {"BizRelationType": BizRelationType},
    semantic_payload_config = semantic_payload_config,
    llm_model = "gpt-4o-mini",
    batch_size = 100,
    overwrite = True,
    client = None
    )
    
    tasks.append(task)

print(f"\nExecuting {len(tasks)} tasks concurrently...")
results = await asyncio.gather(*tasks)
print("All tasks completed.")

# %%
from datetime import datetime as dt

for result in results:
    event_relations_list = result[0]['processed']
    event_ids = result[0]['processed_ids']
    for event_id, relation_model in zip(event_ids, event_relations_list):

        event = event_dict[event_id]

        event.metadata = {}
        event.metadata['_event_id'] = relation_model.id_
        if relation_model.id_ != event.event_id:
            raise ValueError("Ids in event and relation model should be equal.")
        event.metadata['_event_type'] = relation_model.type_
        if relation_model.type_ != event.field:
            raise ValueError("Types in event and relation model should be equal.")
        date = dt.strptime(relation_model.date_, "%Y-%m-%dT%H:%M:%S%z")
        event.metadata['_event_date'] = date
        if date != event.event_date:
           raise ValueError("Dates in event and relation model should be equal.")
        event.metadata['_event_s3_path'] = event.s3_path
        # event.metadata['event_formatted'] = event.formatted
        event.metadata['_xrel_s3_path'] = relation_model.s3_path_
        event.metadata['_xrel_status'] = relation_model.status_
        
        event.processed = {}
        event.processed['_xrel_thinking'] = relation_model.thinking
        event.processed['_xrel_relations'] = relation_model.relations
        event.processed['_xrel_result_value'] = relation_model.result_value_

# %%
keys = list(event_dict.keys())
event = event_dict[keys[5]]
event.processed

# %% [markdown]
# # Build the graph

# %%
import_or_reload("graph.graph_converter")
from graph.graph_converter import generate_graph_elements

nodes, edges = generate_graph_elements(event_dict)

# %%
from neo4j import GraphDatabase

# URI examples: "neo4j://localhost", "neo4j+s://xxx.databases.neo4j.io"
NEO4J_URI = os.getenv("NEO4J_URI", "")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME", "")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD", "")

AUTH = (NEO4J_USERNAME, NEO4J_PASSWORD)

with GraphDatabase.driver(NEO4J_URI, auth=AUTH) as driver:
    driver.verify_connectivity()

# Import the new neo4j_uploader module
import_or_reload("graph.utils.neo4j_uploader")
from graph.utils.neo4j_uploader import upload_graph_to_neo4j

# Upload the graph data to Neo4j
# Set clear_db=True if you want to clear the database before uploading (be careful in production)
upload_graph_to_neo4j(NEO4J_URI, AUTH, nodes, edges, clear_db=True)
